# %% [markdown]
# # Starten wir

# %%
# Dieses Notebook fasst Programmiercode und Erklärungen zusammen. 
# Damit der Computer die Erklärungen nicht auch als Programm auffässt und diese ausführen will, 
# was zu Fehlermeldungen führen würde, da diese nicht der Sprache entsprechen, die er interpretieren kann,
# sind Kommentare oder Erläuterungen hier und in der Programmierung an sich meist mit einem # versehen.
# So ignoriert der Computer diese Zeilen und führt nur den "eigentlichen" Code (ohne einem # davor) aus.

# %%
# Falls du dies einmal ausprobieren möchtest, markiere die folgende Zeile (gehe auf sie, sodass sie 
# vorn am Anfang blau hervorgehoben ist) und drücke dann oben auf Run.

# %%
Hier probiere ich einen Befehl aus, den der Computer so nicht auffassen kann.
# Out:
#   Cell In[32], line 1
#     Hier probiere ich einen Befehl aus, den der Computer so nicht auffassen kann.
#          ^
# SyntaxError: invalid syntax

# %%
# Als Rückmeldung erhälst du SyntaxError - was bedeuet, dass der Computer diese Anweisung nicht entschlüsseln kann.

# %%
# Weiter geht`s.

# Es ist wichtig, dass du dieses Notebook NACHEINANDER ausführst. Gehe also von oben nach unten vor.
# Wenn du weiter unten einen Befehl ausführst, für den die notwendigen Befehle davor nicht ausgeführt wurden,
# wird dir eine Fehlermeldung ausgegeben.
# Wichtig ist auch, wenn du das Notebook schließt und dann wieder öffnest, wieder von vorn zu beginnen.

# Immer wenn der Computer arbeitet und einen Befehl ausführt, steht vor der Zeile in den [] ein *.
# Sobald dieses weg ist, ist der Befehl erfolgreich ausgeführt.
# Falls das nicht geklappt haben sollte, erhälst du eine Fehlermeldung.

# %% [markdown]
# # Beispiel: Analyse der Märchen der Brüder Grimm

# %%
# Kommen wir nun zu unserem Beispiel - der Analyse der Grimm`schen Märchen.

# Zuerst benötigen wir die Texte der Grimm`schen Märchen.
# Es gibt viele Textsammlungen im Internet, die wissenschaftlich ausgebaut wurden.
# Eine bekannte ist das DTA - das Deutsche Textarchiv, dass tausende Texte aus Literatur, Wissenschaft oder Belletristik
# bereitstellt - häufig sogar als Originalausgaben. 
# Das ermöglicht es, auch sehr alte Werke anzusehen.
# Neben dem Scan der ursprünglichen Inhaltsseiten (also der digtial-bildlichen Archivierung dieser Werke) 
# sind auch die Textdaten in verschiedenen Formaten archiviert. 
# Mit ihnen kann man weiterarbeiten und diese computerbasiert analysieren. 

# Falls ihr euch einmal selbst auf der Seite des DTA´s umsehen wollt, geht zu https://www.deutschestextarchiv.de/

# %% [markdown]
# # Notwendige Voraussetzungen

# %%
# Die Texte, die wir benötigen sind die Kinder- und Hausmärchen der Brüder Grimm, Teil 1 und Teil 2.

# Die Texte befinden sich hier:
# https://www.deutschestextarchiv.de/book/show/grimm_maerchen01_1857
# https://www.deutschestextarchiv.de/book/show/grimm_maerchen02_1857

# %%
# Diese Daten müssen für die Analyse in einem bestimmten Format vorliegen. 
# Damit wir sie hier ohne Probleme einbinden können, habe ich die lesbaren Daten in einem Ordner abgelegt, 
# auf den mit den unteren Befehlen zugegriffen werden kann.

# %%
# Weiterhin benötigen wir sogenannte Infrastrukturen - das sind Pakete oder Bibliotheken, 
# die vorprgrammiert sind und uns einige Befehle einfacher ausführen lassen. 
# Durch sie kann beispielsweise ermöglicht werden, mathematische Operationen einfach durchzuführen oder
# Dateien zu laden, damit mit ihnen weitergearbeitet werden kann.

# %%
# Führe die nächsten Zeilen aus, indem du auf sie gehst, bis sie vorn blau markiert sind.
# Wenn sie blau markiert sind, drücke oben auf den Button Run.

# Die Befehle pip install installieren die bestimmten Infrastrukturen 
# und die Befehle import rufen diese auf, damit wir sie nutzen können.

# %%
# !pip install requests
import requests
# Out:
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\kf2\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\kf2\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\kf2\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\kf2\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\kf2\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\kf2\anaconda3\lib\site-packages)
# Requirement already satisfied: requests in c:\users\kf2\anaconda3\lib\site-packages (2.28.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\kf2\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kf2\anaconda3\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\kf2\anaconda3\lib\site-packages (from requests) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kf2\anaconda3\lib\site-packages (from requests) (2024.2.2)

# %%
# !pip install scikit-learn
from sklearn.feature_extraction.text import TfidfVectorizer
# Out:
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\kf2\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\kf2\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\kf2\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\kf2\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\kf2\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\kf2\anaconda3\lib\site-packages)
# Requirement already satisfied: scikit-learn in c:\users\kf2\anaconda3\lib\site-packages (1.2.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\kf2\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\kf2\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\kf2\anaconda3\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\kf2\anaconda3\lib\site-packages (from scikit-learn) (1.10.0)

# %%
from collections import Counter

# %%
# !pip install wordcloud
from wordcloud import WordCloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\kf2\anaconda3\lib\site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\kf2\anaconda3\lib\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\kf2\anaconda3\lib\site-packages (from wordcloud) (3.7.0)
# Requirement already satisfied: pillow in c:\users\kf2\anaconda3\lib\site-packages (from wordcloud) (10.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\kf2\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kf2\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\kf2\anaconda3\lib\site-packages (from matplotlib->wordcloud) (23.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\kf2\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kf2\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kf2\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kf2\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: six>=1.5 in c:\users\kf2\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\kf2\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\kf2\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\kf2\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\kf2\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\kf2\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\kf2\anaconda3\lib\site-packages)

# %%
import string

# %%
# !pip install pandas
import pandas as pd
# Out:
# Requirement already satisfied: pandas in c:\users\kf2\anaconda3\lib\site-packages (2.2.2)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\kf2\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\kf2\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\kf2\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\kf2\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\kf2\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\kf2\anaconda3\lib\site-packages)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kf2\anaconda3\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kf2\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kf2\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\kf2\anaconda3\lib\site-packages (from pandas) (1.24.4)
# Requirement already satisfied: six>=1.5 in c:\users\kf2\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
# !pip install matplotlib
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: matplotlib in c:\users\kf2\anaconda3\lib\site-packages (3.7.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kf2\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kf2\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\kf2\anaconda3\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\kf2\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kf2\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\kf2\anaconda3\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kf2\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: numpy>=1.20 in c:\users\kf2\anaconda3\lib\site-packages (from matplotlib) (1.24.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\kf2\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\kf2\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\kf2\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\kf2\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\kf2\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\kf2\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\kf2\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\kf2\anaconda3\lib\site-packages)

# %%
# braucht man die folgenden unbedingt? final prüfen

# %%
# !pip install gensim nltk
from gensim import corpora, models
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
# Out:
# Requirement already satisfied: gensim in c:\users\kf2\anaconda3\lib\site-packages (4.3.0)
# Requirement already satisfied: nltk in c:\users\kf2\anaconda3\lib\site-packages (3.7)
# Collecting FuzzyTM>=0.4.0
#   Using cached FuzzyTM-2.0.9-py3-none-any.whl (31 kB)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\kf2\anaconda3\lib\site-packages (from gensim) (1.26.4)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\kf2\anaconda3\lib\site-packages (from gensim) (5.2.1)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\kf2\anaconda3\lib\site-packages (from gensim) (1.10.0)
# Requirement already satisfied: joblib in c:\users\kf2\anaconda3\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: click in c:\users\kf2\anaconda3\lib\site-packages (from nltk) (8.0.4)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\kf2\anaconda3\lib\site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: tqdm in c:\users\kf2\anaconda3\lib\site-packages (from nltk) (4.64.1)
# Requirement already satisfied: pandas in c:\users\kf2\anaconda3\lib\site-packages (from FuzzyTM>=0.4.0->gensim) (2.2.2)
# Collecting pyfume
#   Using cached pyFUME-0.3.4-py3-none-any.whl (60 kB)
# Requirement already satisfied: colorama in c:\users\kf2\anaconda3\lib\site-packages (from click->nltk) (0.4.6)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kf2\anaconda3\lib\site-packages (from pandas->FuzzyTM>=0.4.0->gensim) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kf2\anaconda3\lib\site-packages (from pandas->FuzzyTM>=0.4.0->gensim) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kf2\anaconda3\lib\site-packages (from pandas->FuzzyTM>=0.4.0->gensim) (2022.7)
# Collecting numpy>=1.18.5
#   Using cached numpy-1.24.4-cp310-cp310-win_amd64.whl (14.8 MB)
# Collecting fst-pso==1.8.1
#   Using cached fst_pso-1.8.1-py3-none-any.whl
# Requirement already satisfied: simpful==2.12.0 in c:\users\kf2\anaconda3\lib\site-packages (from pyfume->FuzzyTM>=0.4.0->gensim) (2.12.0)
# Collecting pandas
#   Downloading pandas-1.5.3-cp310-cp310-win_amd64.whl (10.4 MB)
#      ---------------------------------------- 10.4/10.4 MB 7.0 MB/s eta 0:00:00
# Collecting scipy>=1.7.0
#   Using cached scipy-1.10.1-cp310-cp310-win_amd64.whl (42.5 MB)
# Collecting miniful
#   Using cached miniful-0.0.6-py3-none-any.whl
# Requirement already satisfied: six>=1.5 in c:\users\kf2\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->FuzzyTM>=0.4.0->gensim) (1.16.0)
# Installing collected packages: numpy, scipy, pandas, miniful, fst-pso, pyfume, FuzzyTM
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\kf2\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\kf2\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\kf2\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\kf2\anaconda3\lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] Zugriff verweigert: 'C:\\Users\\kf2\\anaconda3\\Lib\\site-packages\\~umpy.libs\\libopenblas64__v0.3.23-293-gc2f4bdbb-gcc_10_3_0-2bde3a66a51006b2b53eb373ff767a3f.dll'
# Consider using the `--user` option or check the permissions.
#
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\kf2\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\kf2\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\kf2\anaconda3\lib\site-packages)
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\kf2\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Laden wir uns nun noch die Kinder- und Hausmärchen der Brüder Grimm - Band 1 und 2. 
# Sie liegen auf der Instanz GitHub, die kostenfrei das Teilen von Programmierressourcen ermöglicht.

# Führe die nächste Zeile aus, indem du auf sie gehst, bis sie vorn blau markiert ist.
# Wenn sie blau markiert ist, drücke oben auf den Button Run.

# Wir weisen hier unsere Dateien, die sich in dem angegebenen Pfad befinden, einer Variable (je url1 und url2) zu.

# %%
url1 = 'https://raw.githubusercontent.com/kf619/einfacheTextanalyse/main/data/grimm_maerchen01_1857.txt'
url2 = 'https://raw.githubusercontent.com/kf619/einfacheTextanalyse/main/data/grimm_maerchen02_1857.txt'

# %% [markdown]
# # Laden der Texte

# %%
# Nun wissen wir zwar, wo sich unsere Texte befinden, wir konnten sie aber noch nicht ansehen.
# Wir müssen sie zunächst in unser Notebook laden.
# Dazu verwenden wir den folgenden Code, der festlegt, dass über die URLs die Texte geladen werden.

# Führe die nächste Zeile aus, indem du auf sie gehst, bis sie vorn blau markiert ist.
# Wenn sie blau markiert ist, drücke oben auf den Button Run.

# %%
text1 = requests.get(url1).text
text2 = requests.get(url2).text

# %%
# Schauen wir uns url1 bzw. text1 - die Grimm`schen Hausmärchen Teil 1 und url2 bzw. text2 Teil 2 der Sammlung an. 

# Führe die nächste Zeile aus, indem du auf sie gehst, bis sie vorn blau markiert ist.
# Wenn sie blau markiert ist, drücke oben auf den Button Run. 
# Darunter werden dir nun viele Zeichen angezeigt, die Inhalte aus den Märchen, in einem etwas anderen Format.

# %%
text1
text2
# Out:
# '[0001]\n\x0c\n[0002]\n\x0c\n[0003]\n\x0c\n[0004]\n\x0c\n[0005]\n\n[Abbildung\tMÄRCHENFRAU. \tL. E. Grimm Stahlstich v H.Leedel Göttg]\n\x0c\n[0006]\n\x0c\n[[I]/0007]\nKinder\nund\nHausmärchen\ngesammelt\ndurch\ndie Brüder Grimm.\n\n\nZweiter Band.\n\n\nGroße Ausgabe.\nSiebente Auflage.\n\n\nGöttingen.\nVerlag der Dieterichschen Buchhandlung.\n1857.\n\x0c\n[[II]/0008]\n\x0c\n[[III]/0009]\nJnhalt.\n\n\n87. Der Arme und der Reiche Seite 1\n\n88. Das singende springende Löweneckerchen — 6\n\n89. Die Gänsemagd — 13\n\n90. Der junge Riese — 20\n\n91. Dat Erdmänneken — 29\n\n92. Der König vom goldenen Berge — 35\n\n93. Die Rabe — 42\n\n94. Die kluge Bauerntochter — 49\n\n95. Der alte Hildebrand — 53\n\n96. De drei Vügelkens — 57\n\n97. Das Wasser des Lebens — 62\n\n98. Doctor Allwissend — 69\n\n99. Der Geist im Glas — 72\n\n100. Des Teufels rußiger Bruder — 77\n\n101. Der Bärenhäuter — 81\n\n102. Der Zaunkönig und der Bär — 87\n\n103. Der süße Brei — 90\n\n104. Die klugen Leute — 91\n\n105. Märchen von der Unke — 96\n\n106. Der arme Müllerbursch und das Kätzchen — 98\n\n107. Die beiden Wanderer — 102\n\n108. Hans mein Jgel — 114\n\n109. Das Todtenhemdchen — 120\n\n110. Der Jude im Dorn — 121\n\n111. Der gelernte Jäger — 126\n\n112. Der Dreschflegel vom Himmel — 133\n\n113. De beiden Kün
# %%
# Super, das hat gut geklappt. 
# Der wichtigste Grundstein ist gelegt.
# Weiter geht`s mit der Vorverarbeitung der Textdaten, die wichtig ist, damit der Computer beispielsweise
# Sonderzeichen oder Satzzeichen behandeln kann, ohne, dass wir Fehlermeldungen ausgegeben bekommen.
# Wie du oben siehst, sind ja einige Zeichen in den Texten enthalten, die wir nicht brauchen.

# %% [markdown]
# # Vorverarbeitung und Vorbereitung der Textdaten für die Analyse

# %%
# Wir müssen zunächst die Texte auf Kleinschreibung vereinheitlichen, damit der Computer diese besser lesen kann.

# Außerdem führen wir ein sogenanntes Preprocessing durch - also eine Vorverarbeitung. Dabei werden 
# Sonderzeichen wie ,#*!& usw. gelöscht, da diese uns für unsere inhaltliche Analyse nicht sehr nützlich sind.

# Da, vor allem in Märchen, zahlreiche Füllwörter wie Präpositionen, Adverben, Konjunktionen oder Partikel verwendet werden,
# sollten wir auch diese eliminieren. Sie geben uns nur wenig Aufschluss hinsichtlich des Inhalts.
# Dies erledigen wir über eine sogenannte Stop-words-Liste - Wörter, die wir nicht benötigen.
# Sie kann hier individuell angepasst werden, es gibt aber auch bereits vorgefertigte Listen in anderen Sprachen.

# Führe die nächsten Zeilen aus, indem du auf sie gehst, bis sie vorn blau markiert sind.
# Wenn sie blau markiert sind, drücke oben auf den Button Run. 
# Wenn dir keine Fehlermeldung ausgegeben wird, hast du alles richtig gemacht.

# %%
def preprocess_text(text, stop_words):
   
    text = text.lower()
    
    text = ''.join(char for char in text if char.isalpha() or char.isspace())
    
    words = text.split() 
    words = [word for word in words if word not in stop_words] 
    
    return ' '.join(words) 

german_stop_words = [
    'aber', 'alle', 'allem', 'allen', 'aller', 'alles', 'als', 'also', 'am', 'an', 'ander', 'andere', 'anderem',
    'anderen', 'anderer', 'anderes', 'anderm', 'andern', 'anderr', 'anders', 'auch', 'auf', 'aus', 'bei', 'bin',
    'bis', 'bist', 'da', 'damit', 'dann', 'das', 'dasselbe', 'dazu', 'daß', 'de', 'dein', 'deine', 'deinem', 'deinen',
    'deiner', 'deines', 'dem', 'demselben', 'den', 'denn', 'denselben', 'der', 'derer', 'derselbe', 'derselben',
    'des', 'desselben', 'dessen', 'dich', 'die', 'dies', 'diese', 'dieselbe', 'dieselben', 'diesem', 'diesen',
    'dieser', 'dieses', 'dir', 'do' , 'doch', 'dort', 'du', 'durch', 'ein', 'eine', 'einem', 'einen', 'einer', 'eines',
    'einig', 'einige', 'einigem', 'einigen', 'einiger', 'einiges', 'einmal', 'er', 'es', 'etwas', 'euch', 'euer',
    'eure', 'eurem', 'euren', 'eurer', 'eures', 'für', 'gegen', 'gewesen', 'hab', 'habe', 'haben', 'hat', 'hatte',
    'hatten', 'he', 'hier', 'hin', 'hinter', 'ich', 'ihm', 'ihn', 'ihnen', 'ihr', 'ihre', 'ihrem', 'ihren', 'ihrer',
    'ihres', 'im', 'in', 'indem', 'ins', 'ist', 'jede', 'jedem', 'jeden', 'jeder', 'jedes', 'jene', 'jenem',
    'jenen', 'jener', 'jenes', 'jetzt', 'kann', 'kein', 'keine', 'keinem', 'keinen', 'keiner', 'keines', 'können',
    'könnte', 'machen', 'man', 'manche', 'manchem', 'manchen', 'mancher', 'manches', 'mein', 'meine', 'meinem',
    'meinen', 'meiner', 'meines', 'mit', 'muss', 'musste', 'nach', 'nicht', 'nichts', 'noch', 'nun', 'nur', 'ob',
    'oder', 'ohne', 'se', 'sehr', 'sein', 'seine', 'seinem', 'seinen', 'seiner', 'seines', 'selbst', 'sich', 'sie',
    'sind', 'so', 'solche', 'solchem', 'solchen', 'solcher', 'solches', 'soll', 'sollte', 'sondern', 'sonst',
    'über', 'um', 'un' , 'und', 'uns', 'unser', 'unsere', 'unserem', 'unseren', 'unseres', 'unter', 'viel', 'vom', 'von',
    'vor', 'während', 'war', 'waren', 'warst', 'was', 'weg', 'weil', 'weiter', 'welche', 'welchem', 'welchen',
    'welcher', 'welches', 'wenn', 'werde', 'werden', 'wie', 'wieder', 'will', 'wir', 'wird', 'wirst', 'wo', 'wollen',
    'wollte', 'würde', 'würden', 'zu', 'zum', 'zur', 'zwar', 'zwischen'
]

preprocessed_text1 = preprocess_text(text1, german_stop_words)
preprocessed_text2 = preprocess_text(text2, german_stop_words)

# %%
# Schauen wir uns an, ob es funktioniert hat.

# Führe die nächsten Zeilen aus, indem du auf sie gehst, bis sie vorn blau markiert sind.
# Wenn sie blau markiert sind, drücke oben auf den Button Run.

# Darunter müssten dir nun beide Texte in einer etwas anderen Form ausgegeben werden.

# %%
print(preprocessed_text1)  
print(preprocessed_text2)
# Out:
# abbildung i kinder hausmärchen gesammelt brüder grimm erster band große ausgabe siebente auflage göttingen verlag dieterichschen buchhandlung ii sage vergeht nie ganz verbreitete völker redende lippe umschwebt unsterbliche göttin hesiod iii frau bettina arnim iv v liebe bettine buch kehrt abermals jhnen ausgeflogene taube heimat sucht friedlich sonnt fünf zwanzig jahren jhnen arnim zuerst grün eingebunden goldenem schnitt weihnachtsgeschenke gelegt freute werth hielt konnte schönern dank sagen zeit wochen cassel zubrachte herausgabe angetrieben nahm theil eigenthümliches leben zeigte kleinste beachtete grünes blatt feldblume besonderem geschick anzufassen sinnvoll betrachten wußte unsern sammlungen gefielen märchen besten meinte sollten lange zurückhalten streben vollständigkeit sache ende liegen bliebe schon reinlich sauber geschrieben fügte gutmüthiger jronie hinzu kühnen lesbaren zügen hand schien deutliche schrift halten jm zimmer vi abgehend las einzelnen blätter zahmer kanarienvogel zierlicher bewegung flügeln gleichgewicht haltend kopfe saß vollen locken behaglich schien edle haupt ruht schon seit jahren grab heute bewegt mich erinnerung daran hätte erst gestern letztenmal gesehen stände grüner erde baum krone morgensonne schüttelt jhre kinder groß geworden bedürfen märchen mehr schwerlich veran
# Wir können mit der eigentlichen Analyse beginnen.

# %% [markdown]
# # Analyse

# %%
# Wir werden uns zuerst eine Liste von Begriffen ausgeben lassen, die häufig in den beiden Textsammlungen
# vorkommen. So können wir sie charakterisieren. 

# Dazu führen wir zuerst eine Analyse der Häufigkeiten von Begriffen in den einzelnen Märchen der zwei Bände
# sowie die Analyse der zwei Bände im Verhältnis aus.

# Führe die nächsten Zeilen aus, indem du auf sie gehst, bis sie vorn blau markiert sind.
# Wenn sie blau markiert sind, drücke oben auf den Button Run.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd

# %%
texts = [preprocessed_text1, preprocessed_text2]

# %%
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(texts)

# %%
feature_names = vectorizer.get_feature_names_out()
df_tfidf = pd.DataFrame(tfidf_matrix.T.toarray(), index=feature_names, columns=['preprocessed_text1', 'preprocessed_text2'])

# %%
# Schauen wir uns häufig auftretende Wörter aus den beiden Bänden an. 
# Führe die nächsten Zeilen aus, indem du auf sie gehst, bis sie vorn blau markiert sind.
# Wenn sie blau markiert sind, drücke oben auf den Button Run.

# %%
print("Top-Schlüsselwörter für Märchen Band 1:")
print(top_keywords_text1)


print("Top-Schlüsselwörter für Märchen Band 2:")
print(top_keywords_text2)
# Out:
# Top-Schlüsselwörter für Märchen Band 1:
# sprach        0.429668
# könig         0.215995
# kam           0.199738
# gieng         0.183480
# mir           0.175583
# antwortete    0.156074
# sagte         0.154216
# frau          0.126810
# mich          0.118914
# sah           0.117055
# mann          0.113804
# ward          0.108230
# rief          0.108230
# fort          0.092437
# wäre          0.091043
# haus          0.084540
# ließ          0.082682
# konnte        0.082218
# nahm          0.079895
# wohl          0.079895
# vater         0.078966
# ja            0.077572
# dat           0.076179
# mädchen       0.075714
# ach           0.075714
# Name: preprocessed_text1, dtype: float64
# Top-Schlüsselwörter für Märchen Band 2:
# sprach        0.372133
# sagte         0.220523
# mir           0.208642
# gieng         0.189156
# kam           0.182502
# könig         0.127847
# mich          0.125946
# wäre          0.115490
# dat           0.111688
# sah           0.107885
# mann          0.102657
# ward          0.101707
# alte          0.100756
# drei          0.099331
# antwortete    0.096004
# vater         0.093152
# konnte        0.091251
# rief          0.089825
# ließ          0.088399
# hätte         0.088399
# hast          0.085073
# schon         0.084597
# mehr          0.084122
# frau          0.084122
# haus          0.081270
# Name: preprocessed_text2, dtype: float64

# %%
# Wir vernachlässigen einmal die Verben, die sich um das Thema Sprechen, Antworten und Kommunizieren drehen und 
# schauen uns die Substantive einmal genauer an:

# In Band 1 tauchen die Begriffe König, Frau, Mann, Haus, Vater und Mädchen häufig auf.
# In Band 2 die Begriffe König, Mann, Alte, Vater, Frau, Haus. 

# Das könnte bedeuten, dass im Band 1 der Kinder- und Hausmärchen eher Kinder oder Jugendliche (da Mädchen)
# und im Band 2 der Kinder- und Hausmärchen eher Erwachsene in den jeweiligen Märchen thematisiert werden.

# %%
# Wir wollen uns das einmal grafisch ausgeben lassen.
# So können wir auch ein Gefühl für deren Wichtigkeit erlangen. 
# Wir erstellen uns eine sogenannte Wordcloud, die diese Begriffe beinhaltet.

# Führe die nächsten Zeilen aus, indem du auf sie gehst, bis sie vorn blau markiert sind.
# Wenn sie blau markiert sind, drücke oben auf den Button Run.

# %%
Band1 = ['könig', 'frau', 'mann', 'haus', 'vater', 'mädchen']
wordcloud_Band1= WordCloud(width=800, height=400, background_color='white').generate(' '.join(Band1))

# %%
# nun die Ausgabe:

# %%
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud_Band1, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# und noch einmal für die zentralen Begriffe aus dem 2. Band der Märchensammlung

# %%
Band2 = ['könig', 'mann', 'alte', 'vater', 'frau', 'haus']
wordcloud_Band2 = WordCloud(width=800, height=400, background_color='white').generate(' '.join(Band2))

# %%
# und die Ausgabe:

# %%
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud_Band2, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# Wir sehen in diesen Wordclouds wichtige Begriffe der jeweiligen Textsammlung. 
# Dies muss natürlich immer interpretiert werden, aber wir haben nun einen ersten Eindruck, dass sich die beiden
# Bände der Märchen inhaltlich sehr ähneln (was auch naheliegt, da sie von den gleichen Autoren stammen),
# aber es gibt auch Punkte, wo sie sich unterscheiden.

# %%
# Dies war noch kein Maschinelles Lernen, aber eine gute Option, einen Eindruck der beiden Texte zu erhalten.
# Überprüfen wir nun also, aus welchem Band unsere beiden Textauszüge stammen könnten.

# %% [markdown]
# # Nun lassen wir uns vorhersagen, aus welcher Textsammlung unser Auszug stammt

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
vectorizer = TfidfVectorizer()
tfidf_matrix_text1 = vectorizer.fit_transform([preprocessed_text1])
tfidf_matrix_text2 = vectorizer.transform([preprocessed_text2])

# %%
neuer_text = "Der Fuchs kam einmal auf eine Wiese, wo eine Herde schöner fetter Gänse saß, da lachte er und sprach ‘ich komme ja wie gerufen, ihr sitzt hübsch beisammen, so kann ich eine nach der andern auffressen.’ Die Gänse gackerten vor Schrecken, sprangen auf, fiengen an zu jammern und kläglich um ihr Leben zu bitten. Der Fuchs aber wollte auf nichts hören und sprach ‘da ist keine Gnade, ihr müßt sterben.’ Endlich nahm sich eine das Herz und sagte ‘sollen wir armen Gänse doch einmal unser jung frisch Leben lassen, so erzeige uns die einzige Gnade und erlaub uns noch ein Gebet, damit wir nicht in unsern Sünden sterben: hernach wollen wir uns auch in eine Reihe stellen, damit du dir immer die fetteste aussuchen kannst.’ ‘Ja,’ sagte der Fuchs, ‘das ist billig, und ist eine fromme Bitte: betet, ich will so lange warten.’ Also fieng die erste ein recht langes Gebet an, immer ‘ga! ga!’ und weil sie gar nicht aufhören wollte, wartete die zweite nicht, bis die Reihe an sie kam, sondern fieng auch an ‘ga! ga!’ Die dritte und vierte folgte ihr, und bald gackerten sie alle zusammen. (Und wenn sie ausgebetet haben, soll das Märchen weiter erzählt werden, sie beten aber alleweile noch immer fort.)"

# %%
preprocessed_neuer_text = preprocess_text(neuer_text, german_stop_words)

# %%
tfidf_matrix_neuer_text = vectorizer.transform([preprocessed_neuer_text])

# %%
similarity_to_text1 = cosine_similarity(tfidf_matrix_neuer_text, tfidf_matrix_text1)
similarity_to_text2 = cosine_similarity(tfidf_matrix_neuer_text, tfidf_matrix_text2)

# %%
print(f"Ähnlichkeit zu Text 1: {similarity_to_text1[0][0]}")
print(f"Ähnlichkeit zu Text 2: {similarity_to_text2[0][0]}")

if similarity_to_text1 > similarity_to_text2:
    print(f"Der neue Text '{neuer_text}' gehört eher zu den Kinder- und Hausmärchen Band 1.")
else:
    print(f"Der neue Text '{neuer_text}' gehört eher zu den Kinder- und Hausmärchen Band 2.")
# Out:
# Ähnlichkeit zu Text 1: 0.27502358326708287
# Ähnlichkeit zu Text 2: 0.25925498344303327
# Der neue Text 'Der Fuchs kam einmal auf eine Wiese, wo eine Herde schöner fetter Gänse saß, da lachte er und sprach ‘ich komme ja wie gerufen, ihr sitzt hübsch beisammen, so kann ich eine nach der andern auffressen.’ Die Gänse gackerten vor Schrecken, sprangen auf, fiengen an zu jammern und kläglich um ihr Leben zu bitten. Der Fuchs aber wollte auf nichts hören und sprach ‘da ist keine Gnade, ihr müßt sterben.’ Endlich nahm sich eine das Herz und sagte ‘sollen wir armen Gänse doch einmal unser jung frisch Leben lassen, so erzeige uns die einzige Gnade und erlaub uns noch ein Gebet, damit wir nicht in unsern Sünden sterben: hernach wollen wir uns auch in eine Reihe stellen, damit du dir immer die fetteste aussuchen kannst.’ ‘Ja,’ sagte der Fuchs, ‘das ist billig, und ist eine fromme Bitte: betet, ich will so lange warten.’ Also fieng die erste ein recht langes Gebet an, immer ‘ga! ga!’ und weil sie gar nicht aufhören wollte, wartete die zweite nicht, bis die Reihe an sie kam, sondern fieng auch an ‘ga! ga!’ Die dritte und vierte folgte ihr, und bald gackerten sie alle zusammen. (Und wenn sie ausgebetet haben, soll das Märchen weiter erzählt werden, sie beten aber alleweile noch immer fort.)' gehört eher zu den Kinder- und Hausmärchen Band 1.

# %%
# Der Text ist also mit einer höheren Wahrscheinlichkeit zum Band 1 der Kinder- und Hausmärchen zuzurechnen.
# Kann das stimmen?

# %%
# Um das schnell zu überprüfen, schauen wir direkt im Werk nach.
# Gehe zu https://www.deutschestextarchiv.de/book/show/grimm_maerchen01_1857 und klicke im Inhaltsverzeichnis
# das Märchen Nummer 86 an. 
# Du kommst zum Märchen Der Fuchs und die Gänse. 
# Wenn du die erste Zeilen liest, siehst du, dass sie unser Beispiel sind.

# Ich habe diesen Text aus der Sammlung für das Training des Algorithmus herausgenommen.
# Unser Algorithmus ordnet das Märchen richtig dem Band 1 der Kinder- und Hausmärchen zu. 
# Zwar sind die zwei Märchenbände sehr ähnlich, da es sich in den Märchen selbst um ähnliche Dinge dreht,
# dennoch arbeitet das Maschinelle Lernen hier für uns - und das korrekt.

# %% [markdown]
# # Super, du hast es geschafft!

# %%
# Du hast dieses Beispiel erfolgreich durchlaufen und Maschinelles Lernen erprobt.
# Kehre nun zum Kurs zurück und rekapituliere das Gelernte.
